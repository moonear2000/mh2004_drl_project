# %%
import argparse
import os
from copy import deepcopy
from typing import Optional, Tuple

import gymnasium as gym
import numpy as np
import torch
from pettingzoo.classic import hanabi_v4
from torch.utils.tensorboard import SummaryWriter
from torch.distributions import Independent, Normal

from tianshou.data import Collector, VectorReplayBuffer
from tianshou.env import DummyVectorEnv
from tianshou.env.pettingzoo_env import PettingZooEnv
from tianshou.policy import (
    MultiAgentPolicyManager,
    PPOPolicy
)
from tianshou.utils import TensorboardLogger
from tianshou.utils.net.common import Net
from tianshou.utils.net.common import ActorCritic, Net
from tianshou.utils.net.continuous  import ActorProb, Critic
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %%
p = {
    'hidden_layers': [256,256],
    'gamma': 0.99,
    'lr': 1e-6,
    'target_update_freq': 200,
    'estimation_steps': 1,
    'num_train':50,
    'num_test':50,
    'buffer_size':50000,
    'batch_size':32,
    'steps_per_collect': 10000,
    'updates_per_train': 500,
    'test_steps': 50000,
    'epochs':1000,
    'test_frequency':5,
    'save_frequency':25,
    'eps':0.01
}
path = 'saved_data/AC_ppo_2/'

# %%
def get_env(render_mode=None):
    return PettingZooEnv(hanabi_v4.env(colors=2, ranks=5, players=2, hand_size=4, max_information_tokens=5,
max_life_tokens=2, observation_type=1))

# %%
def get_agents(
    lr = 1e-4, 
    hidden_layers = [256, 256], 
    gamma = 0.99,
    target_update_freq = 200, 
    estimation_steps = 1, 
    num_train = 50, 
    num_test = 50,
    atom_size = 51,
    noisy_std = 0.1
):
    
    # Return Policy, Agents, Envs
    env = get_env()
    observation_space = env.observation_space['observation'] if isinstance(
    env.observation_space, gym.spaces.Dict
    ) else env.observation_space

    state_shape = observation_space.shape or observation_space.n
    action_shape = env.action_space.shape or env.action_space.n
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    

    net = Net(state_shape, hidden_sizes=hidden_layers, device=device)
    actor = ActorProb(net, action_shape, unbounded=True,
                      device=device).to(device)
    critic = Critic(
        Net(state_shape, hidden_sizes=hidden_layers, device=device),
        device=device
    ).to(device)
    actor_critic = ActorCritic(actor, critic)
    
    for m in actor_critic.modules():
        if isinstance(m, torch.nn.Linear):
            torch.nn.init.orthogonal_(m.weight)
            torch.nn.init.zeros_(m.bias)
    optim = torch.optim.Adam(actor_critic.parameters(), lr=lr)
    
    def dist(*logits):
        return Independent(Normal(*logits), 1)

    policy = PPOPolicy(
        actor,
        critic,
        optim,
        dist,
        discount_factor=gamma
    )
    
    agents = [policy, policy]
    policy = MultiAgentPolicyManager(agents, env)
    agents = env.agents

    train_envs = DummyVectorEnv([get_env for _ in range(num_train)])
    test_envs = DummyVectorEnv([get_env for _ in range(num_test)])
    
    return policy, agents, train_envs, test_envs

# %%
def get_collectors(
    policy,
    train_envs,
    test_envs,
    buffer_size
):
    
    # Get collectors
    train_collector = Collector(
    policy,
    train_envs,
    VectorReplayBuffer(buffer_size, len(train_envs)),
    exploration_noise=True)
    
    test_collector = Collector(policy, test_envs, exploration_noise=True)
    
    return train_collector, test_collector

# %%
def initialize_buffer(
    train_collector,
    buffer_size,
    agents,
    policy,
    eps = 0.1
):
    train_collector.collect(n_step = buffer_size)

# %%
def save_policy(policy, agents):
    for a in agents:
        torch.save(policy.policies[a].state_dict(), f'saved_data/AC_ppo_2/{a}_params.pth')

def save_history(history):
    np.save(f'saved_data/AC_ppo_2/training_rewards.npy', np.array(history))
    
def change_lr(optimizer, new_lr):
    # Run this to change the learning rate to 1e-5:
    for g in optimizer.param_groups:
        g['lr'] = new_lr

# %%
def train(
    policy,
    train_collector,
    test_collector,
    agents,
    epochs=1000,
    collection_steps_per_epoch=10000,
    updates_per_epoch=500,
    test_frequency=5,
    test_steps=50000,
    save_frequency = 50,
    batch_size = 32,
    eps = 0.1,
    training_history = []
):
    for i in tqdm(range(epochs)):
        
        # Collection step
        result = train_collector.collect(n_step = collection_steps_per_epoch)
        
        # Test Step
        if i%test_frequency == 0:
            for a in agents:
                policy.policies[a].set_eps(0)
            result = test_collector.collect(n_step = test_steps)
            mean_reward = result['rews'].mean()
            tqdm.write(str(mean_reward))
            training_history.append(mean_reward)
            for a in agents:
                policy.policies[a].set_eps(eps)
    
        if i%save_frequency == 0:
            save_policy(policy, agents)
            save_history(training_history)
    
        # Update step (one epoch)
        for _ in range(updates_per_epoch): 
            losses = policy.update(batch_size, train_collector.buffer)
    
    plot_and_save(training_history, test_frequency)

# %%
def plot_and_save(training_history, test_frequency, save = True):
    x = np.arange(len(training_history))
    x *= test_frequency
    plt.plot(x, training_history)
    plt.title('Combined Average Score (Rainbow, 2 Color game)')
    plt.xlabel('Epoch')
    plt.ylabel('Average Score (max 10)')
    if save: plt.savefig(f'saved_data/AC_ppo_2/training_curve.png')
        
def load(policy, path, agents):
    for a in agents:
        policy.policies[a].load_state_dict(torch.load(path + f'{a}_params.pth'))
    his = list(np.load(f'saved_data/AC_ppo_2/training_rewards.npy'))
    return his

# %%
policy, agents, train_envs, test_envs = get_agents(lr = p['lr'], hidden_layers = p['hidden_layers'], gamma = p['gamma'], 
    target_update_freq = p['target_update_freq'], estimation_steps = p['estimation_steps'], num_train = p['num_train'], 
    num_test = p['num_test'])
train_collector, test_collector = get_collectors(policy, train_envs, test_envs, buffer_size = p['buffer_size'])
initialize_buffer(train_collector, p['buffer_size'], agents, policy, eps = p['eps'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3957561/1022056751.py in <module>
#       3     num_test = p['num_test'])
#       4 train_collector, test_collector = get_collectors(policy, train_envs, test_envs, buffer_size = p['buffer_size'])
# ----> 5 initialize_buffer(train_collector, p['buffer_size'], agents, policy, eps = p['eps'])
#
# /tmp/ipykernel_3957561/1535219302.py in initialize_buffer(train_collector, buffer_size, agents, policy, eps)
#       6     eps = 0.1
#       7 ):
# ----> 8     train_collector.collect(n_step = buffer_size)
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/data/collector.py in collect(self, n_step, n_episode, random, render, no_grad, gym_reset_kwargs)
#     295                     with torch.no_grad():  # faster than retain_grad version
#     296                         # self.data.obs will be used by agent to get result
# --> 297                         result = self.policy(self.data, last_state)
#     298                 else:
#     299                     result = self.policy(self.data, last_state)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/policy/multiagent/mapolicy.py in forward(self, batch, state, **kwargs)
#     143                 if hasattr(tmp_batch.obs_next, 'obs'):
#     144                     tmp_batch.obs_next = tmp_batch.obs_next.obs
# --> 145             out = policy(
#     146                 batch=tmp_batch,
#     147                 state=None if state is None else state[agent_id],
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/policy/modelfree/pg.py in forward(self, batch, state, **kwargs)
#     106             more detailed explanation.
#     107         """
# --> 108         logits, hidden = self.actor(batch.obs, state=state, info=batch.info)
#     109         if isinstance(logits, tuple):
#     110             dist = self.dist_fn(*logits)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/utils/net/continuous.py in forward(self, obs, state, info)
#     209     ) -> Tuple[Tuple[torch.Tensor, torch.Tensor], Any]:
#     210         """Mapping: obs -> logits -> (mu, sigma)."""
# --> 211         logits, hidden = self.preprocess(obs, state)
#     212         mu = self.mu(logits)
#     213         if not self._unbounded:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/utils/net/common.py in forward(self, obs, state, info)
#     211     ) -> Tuple[torch.Tensor, Any]:
#     212         """Mapping: obs -> flatten (inside MLP)-> logits."""
# --> 213         logits = self.model(obs)
#     214         bsz = logits.shape[0]
#     215         if self.use_dueling:  # Dueling DQN
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/utils/net/common.py in forward(self, obs)
#     107     def forward(self, obs: Union[np.ndarray, torch.Tensor]) -> torch.Tensor:
#     108         if self.device is not None:
# --> 109             obs = torch.as_tensor(obs, device=self.device, dtype=torch.float32)
#     110         if self.flatten_input:
#     111             obs = obs.flatten(1)
#
# ~/anaconda3/lib/python3.9/site-packages/tianshou/data/batch.py in __len__(self)
#     679             if isinstance(obj, Batch) and obj.is_empty(recurse=True):
#     680                 continue
# --> 681             elif hasattr(obj, "__len__") and (isinstance(obj, Batch) or obj.ndim > 0):
#     682                 lens.append(len(obj))
#     683             else:
#
# AttributeError: 'str' object has no attribute 'ndim'

# %%
#training_history = load(policy, path, agents)

# %%
train(policy, train_collector, test_collector, agents,
    epochs=p['epochs'],
    collection_steps_per_epoch=p['steps_per_collect'],
    updates_per_epoch=p['updates_per_train'],
    test_frequency=p['test_frequency'],
    test_steps=p['test_steps'],
    save_frequency = p['save_frequency'],
    batch_size = p['batch_size'],
    eps = p['eps'],
    training_history = training_history)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 8.054115507048659
# 8.042476276547672
# 7.999548532731377
# 8.048670572329879
# 8.079350766456267
# 8.099188458070333
# 8.124943617501128
# 8.032897701667418
# 8.055405405405406
# 8.05507900677201
# 8.083258325832583
# 8.163292847503374
# 8.128262826282628
# 8.103386004514674
# 8.064269662921348
# 8.086642599277978
# 8.131922557406574
# 8.102390617952187
# 8.05103884372177
# 8.10521582733813
# 8.074492099322798
# 8.165693758419398
# 8.11971197119712
# 8.099412562132851
# 8.113758992805755
# 8.056884875846501
# 8.091891891891892
# 8.117303370786518
# 8.085662759242561
# 8.109353818346136
# 8.10153429602888
# 8.124044943820225
# 8.163292847503374
# 8.081227436823104
# 8.105808194506979
# 8.08228417266187
# 8.097968397291197
# 8.049616599007669
# 8.046825754164791
# 8.066335740072201
# 8.115523465703971
# 8.110661268556006
# 8.10158013544018
# 8.119208277103015
# 8.128654970760234
# 8.071139126519586
# 8.074424898511502
# 8.090418353576249
# 8.074224021592443
# 8.110207768744354
# 8.128205128205128
# 8.105168539325843
# 8.115713642503376
# 8.105026929982047
# 8.147629796839729
# 8.05668016194332
# 8.078068592057761
# 8.111211166141377
# 8.099639314697926
# 8.066726780883679
# 8.143115124153498
# 8.067056705670566
# 8.157515751575158
# 8.038409399005875
# 8.082469580892294
# 8.106450157870997
# 8.145299145299145
# 8.147297297297298
# 8.107497741644083
# 8.114620938628159
# 8.101710171017102
# 8.126178715761114
# 8.09590274651058
# 8.075607560756076
# 8.119927862939585
# 8.057761732851986
# 8.061206120612061
# 8.09613656783468
# 8.140603875619648
# 8.145421903052064
# 8.143631436314363
# 8.093285263632266
# 8.12861010830325
# 8.112910481331534
# 8.089309878213802
# 8.156123822341858
# 8.15045045045045
# 8.097791798107256
# 8.171685393258427
# 8.136998648039658
# 8.100991884580703
# 8.12275179856115
# 8.106210621062106
# 8.137122237257556
# 8.134892086330936
# 8.16005410279531
# 8.042304230423042
# 8.113309352517986
# 8.080666967102298
# 8.136302294197032
# 8.125788999098287
# 8.152946468735943
# 8.115211521152116
# 8.08258527827648
# 8.090415913200724
# 8.13515940727436
# 8.075989208633093
# 8.117408906882591
# 8.121402877697841
# 8.13204146011717
# 8.15658844765343
# 8.07370786516854
# 8.127822944896115
# 8.088407758231845
# 8.087758775877587
# 8.049661399548533
# 8.082395317424584
# 8.055405405405406
# 8.121007647323436
# 8.04408457040036
# 8.129438202247192
# 8.157207207207207
# 8.136241007194245
# 8.101717902350813
# 8.150112359550562
# 8.139377537212448
# 8.128539325842697
# 8.143114311431143
